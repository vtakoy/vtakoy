# %%
#task h3.1: Сделать свое решение для этого соревнования https://www.kaggle.com/competitions/digit-recognizer
# Результат: опубликовать решение в разделе. После отправить мне через сайт ку решение и какой у вас получился скор

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Загрузка данных
train = pd.read_csv('C:/Users/vtako/Desktop/Project/DL homework 3/train.csv')
test = pd.read_csv('C:/Users/vtako/Desktop/Project/DL homework 3/test.csv')

# Разделение данных на X и y
y_train = train["label"]
X_train = train.drop(labels = ["label"], axis=1)

# Нормализация данных
X_train = X_train / 255.0
test = test / 255.0

# Изменение формы данных для CNN
X_train = X_train.values.reshape(-1,28,28,1)
test = test.values.reshape(-1,28,28,1)

# Преобразование меток в one-hot encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=10)

# Разделение данных на тренировочную и валидационную выборки
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# Аугментация данных
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1
)
datagen.fit(X_train)

# Построение улучшенной модели CNN
model = Sequential()

# Первый сверточный блок
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', padding='Same', input_shape=(28,28,1)))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Второй сверточный блок
model.add(Conv2D(64, kernel_size=(3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Третий сверточный блок
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# Переход к полносвязным слоям
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# Компиляция модели
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Callback-и
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

# Обучение модели
epochs = 50
batch_size = 128

history = model.fit(
    datagen.flow(X_train, y_train, batch_size=batch_size),
    epochs=epochs, validation_data=(X_val, y_val),
    steps_per_epoch=X_train.shape[0] // batch_size,
    callbacks=[early_stopping, reduce_lr]
)

# Оценка модели
val_loss, val_acc = model.evaluate(X_val, y_val)
print(f"Validation Accuracy: {val_acc * 100:.2f}%")

# Предсказания для тестового набора
predictions = model.predict(test)
predicted_classes = np.argmax(predictions, axis=1)

# Подготовка файла для отправки
submission = pd.DataFrame({
    'ImageId': np.arange(1, len(predicted_classes) + 1),
    'Label': predicted_classes
})

# Сохранение файла
submission.to_csv('C:/Users/vtako/Desktop/Project/DL homework 3/sample_submission.csv', index=False)
# Out:
# Epoch 1/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 73s 232ms/step - accuracy: 0.6970 - loss: 1.1074 - val_accuracy: 0.3876 - val_loss: 3.1554 - learning_rate: 0.0010
# Epoch 2/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9062 - loss: 0.3265 - val_accuracy: 0.3612 - val_loss: 3.3011 - learning_rate: 0.0010
# Epoch 3/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 60s 201ms/step - accuracy: 0.9584 - loss: 0.1402 - val_accuracy: 0.9855 - val_loss: 0.0503 - learning_rate: 0.0010
# Epoch 4/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9766 - loss: 0.0989 - val_accuracy: 0.9869 - val_loss: 0.0483 - learning_rate: 0.0010
# Epoch 5/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 58s 195ms/step - accuracy: 0.9708 - loss: 0.0966 - val_accuracy: 0.9902 - val_loss: 0.0401 - learning_rate: 0.0010
# Epoch 6/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9766 - loss: 0.0806 - val_accuracy: 0.9902 - val_loss: 0.0400 - learning_rate: 0.0010
# Epoch 7/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 53s 177ms/step - accuracy: 0.9759 - loss: 0.0830 - val_accuracy: 0.9907 - val_loss: 0.0343 - learning_rate: 0.0010
# Epoch 8/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.0354 - val_accuracy: 0.9902 - val_loss: 0.0347 - learning_rate: 0.0010
# Epoch 9/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 66s 221ms/step - accuracy: 0.9792 - loss: 0.0664 - val_accuracy: 0.9910 - val_loss: 0.0290 - learning_rate: 0.0010
# Epoch 10/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9910 - val_loss: 0.0295 - learning_rate: 0.0010
# Epoch 11/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 62s 208ms/step - accuracy: 0.9819 - loss: 0.0582 - val_accuracy: 0.9898 - val_loss: 0.0362 - learning_rate: 0.0010
# Epoch 12/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9688 - loss: 0.0528 - val_accuracy: 0.9905 - val_loss: 0.0357 - learning_rate: 0.0010
# Epoch 13/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 62s 209ms/step - accuracy: 0.9834 - loss: 0.0559 - val_accuracy: 0.9924 - val_loss: 0.0261 - learning_rate: 0.0010
# Epoch 14/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9766 - loss: 0.1079 - val_accuracy: 0.9924 - val_loss: 0.0251 - learning_rate: 0.0010
# Epoch 15/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 52s 176ms/step - accuracy: 0.9852 - loss: 0.0501 - val_accuracy: 0.9919 - val_loss: 0.0278 - learning_rate: 0.0010
# Epoch 16/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9844 - loss: 0.0249 - val_accuracy: 0.9919 - val_loss: 0.0278 - learning_rate: 0.0010
# Epoch 17/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 171ms/step - accuracy: 0.9851 - loss: 0.0523 - val_accuracy: 0.9902 - val_loss: 0.0312 - learning_rate: 0.0010
# Epoch 18/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.0425 - val_accuracy: 0.9902 - val_loss: 0.0323 - learning_rate: 0.0010
# Epoch 19/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9860 - loss: 0.0462
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 171ms/step - accuracy: 0.9860 - loss: 0.0462 - val_accuracy: 0.9933 - val_loss: 0.0252 - learning_rate: 0.0010
# Epoch 20/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9844 - loss: 0.0305 - val_accuracy: 0.9933 - val_loss: 0.0255 - learning_rate: 5.0000e-04
# Epoch 21/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 171ms/step - accuracy: 0.9906 - loss: 0.0327 - val_accuracy: 0.9931 - val_loss: 0.0240 - learning_rate: 5.0000e-04
# Epoch 22/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9929 - val_loss: 0.0241 - learning_rate: 5.0000e-04
# Epoch 23/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 171ms/step - accuracy: 0.9907 - loss: 0.0301 - val_accuracy: 0.9933 - val_loss: 0.0234 - learning_rate: 5.0000e-04
# Epoch 24/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9933 - val_loss: 0.0232 - learning_rate: 5.0000e-04
# Epoch 25/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 172ms/step - accuracy: 0.9916 - loss: 0.0297 - val_accuracy: 0.9952 - val_loss: 0.0154 - learning_rate: 5.0000e-04
# Epoch 26/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.0622 - val_accuracy: 0.9948 - val_loss: 0.0156 - learning_rate: 5.0000e-04
# Epoch 27/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 172ms/step - accuracy: 0.9920 - loss: 0.0276 - val_accuracy: 0.9936 - val_loss: 0.0171 - learning_rate: 5.0000e-04
# Epoch 28/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9844 - loss: 0.0721 - val_accuracy: 0.9936 - val_loss: 0.0171 - learning_rate: 5.0000e-04
# Epoch 29/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 172ms/step - accuracy: 0.9921 - loss: 0.0267 - val_accuracy: 0.9943 - val_loss: 0.0197 - learning_rate: 5.0000e-04
# Epoch 30/50
#   1/295 ━━━━━━━━━━━━━━━━━━━━ 49s 169ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9943 - val_loss: 0.0201 - learning_rate: 5.0000e-04
# Epoch 31/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 172ms/step - accuracy: 0.9933 - loss: 0.0229 - val_accuracy: 0.9948 - val_loss: 0.0173 - learning_rate: 2.5000e-04
# Epoch 32/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.0141 - val_accuracy: 0.9948 - val_loss: 0.0170 - learning_rate: 2.5000e-04
# Epoch 33/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 173ms/step - accuracy: 0.9937 - loss: 0.0212 - val_accuracy: 0.9952 - val_loss: 0.0184 - learning_rate: 2.5000e-04
# Epoch 34/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9922 - loss: 0.0099 - val_accuracy: 0.9952 - val_loss: 0.0185 - learning_rate: 2.5000e-04
# Epoch 35/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9933 - loss: 0.0233
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 51s 173ms/step - accuracy: 0.9933 - loss: 0.0233 - val_accuracy: 0.9948 - val_loss: 0.0189 - learning_rate: 2.5000e-04
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9953 - loss: 0.0157
# Validation Accuracy: 99.52%
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step
