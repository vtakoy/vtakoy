# %% [markdown]
# # Задание 1: Химический анализ родника

# %%
import pandas as pd
import re
from IPython.display import display

# Загрузка данных из файла
file_path = 'C:/Users/vtako/Desktop/Project/Homework4/Химический анализ родника в Нескучном саду.csv'
df = pd.read_csv(file_path, sep=';')

# Функция для проверки соответствия значения нормативу
def check_norm(value, norm):
    if 'не более' in norm:
        limit = float(re.findall(r"[-+]?\d*\.\d+|\d+", norm)[0])
        return value <= limit, f"не более {limit}"
    elif 'в пределах' in norm:
        limits = re.findall(r"[-+]?\d*\.\d+|\d+", norm)
        lower_limit = float(limits[0])
        upper_limit = float(limits[1])
        return lower_limit <= value <= upper_limit, f"в пределах {lower_limit}-{upper_limit}"
    else:
        return False, "норматив неизвестен"

# Преобразование столбца "Результат анализа" к числовому типу там, где это возможно
df['Результат анализа'] = pd.to_numeric(df['Результат анализа'], errors='coerce')

# Создание столбца с выводами
df['Вывод'] = df.apply(lambda row: f"Результат анализа {row['Результат анализа']} {row['Единица измерений']} при нормативе {row['Норматив']}. " +
                                   ("Т.о. результат анализа в норме." if check_norm(row['Результат анализа'], row['Норматив'])[0] else "Т.о. результат анализа не в норме."),
                       axis=1)

# Установка столбца "Показатель" в качестве индексного
df.set_index('Показатель', inplace=True)

# Просмотр итогового DataFrame
display(df)

# Сохранение итогового DataFrame в файл Excel
output_file_path = 'C:/Users/vtako/Desktop/Project/Homework4/ВЫВОДЫ Химический анализ родника в Нескучном саду.xlsx'
df.to_excel(output_file_path)
# Out:
#                                       Единица измерений  Результат анализа  \
# Показатель
# pH                                           единицы pH              8.400
# Запах                                             баллы              1.000
# Цветность                                       градусы                NaN
# Жёсткость                                   мг-эквл/дм3              9.200
# Аммиак и аммоний-ион (по азоту)                  мг/дм3              0.420
# Нитриты (по NO2)                                 мг/дм3              0.017
# Нитраты (по NO3)                                 мг/дм3             24.000
# Фосфаты (P)                                      мг/дм3              0.360
# Хлориды (Cl)                                     мг/дм3            200.000
# Сульфаты (SO4)                                   мг/дм3            189.500
# Железо (включая хлорное железо) по Fe            мг/дм3              0.019
# Нефть                                            мг/дм3              0.550
# Общая минерализация (сухой остаток)              мг/дм3            590.000
# Окисляемость перманганатная                      мг/дм3              2.000
#
#                                               Норматив  \
# Показатель
# pH                                      в пределах 6-9
# Запах                                     не более 2-3
# Цветность                                  не более 30
# Жёсткость                              в пределах 7-10
# Аммиак и аммоний-ион (по азоту)           не более 1,5
# Нитриты (по NO2)                          не более 3,3
# Нитраты (по NO3)                           не более 45
# Фосфаты (P)                               не более 3,5
# Хлориды (Cl)                              не более 350
# Сульфаты (SO4)                            не более 500
# Железо (включая хлорное железо) по Fe     не более 0,3
# Нефть                                     не более 0,3
# Общая минерализация (сухой остаток)      не более 1000
# Окисляемость перманганатная               не более 0,5
#
#                                                                                    Вывод
# Показатель
# pH                                     Результат анализа 8.4 единицы pH при нормативе...
# Запах                                  Результат анализа 1.0 баллы при нормативе не б...
# Цветность                              Результат анализа nan градусы при нормативе не...
# Жёсткость                              Результат анализа 9.2 мг-эквл/дм3 при норматив...
# Аммиак и аммоний-ион (по азоту)        Результат анализа 0.42 мг/дм3 при нормативе не...
# Нитриты (по NO2)                       Результат анализа 0.017 мг/дм3 при нормативе н...
# Нитраты (по NO3)                       Результат анализа 24.0 мг/дм3 при нормативе не...
# Фосфаты (P)                            Результат анализа 0.36 мг/дм3 при нормативе не...
# Хлориды (Cl)                           Результат анализа 200.0 мг/дм3 при нормативе н...
# Сульфаты (SO4)                         Результат анализа 189.5 мг/дм3 при нормативе н...
# Железо (включая хлорное железо) по Fe  Результат анализа 0.019 мг/дм3 при нормативе н...
# Нефть                                  Результат анализа 0.55 мг/дм3 при нормативе не...
# Общая минерализация (сухой остаток)    Результат анализа 590.0 мг/дм3 при нормативе н...
# Окисляемость перманганатная            Результат анализа 2.0 мг/дм3 при нормативе не ...
